# %%
import sys
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import pandas as pd
import glob 
import math
import re
from collections import defaultdict
from matplotlib.font_manager import FontProperties
import subprocess
import scipy
from scipy.stats.stats import pearsonr 
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 3 * matplotlib.rcParams['savefig.dpi']

# %%
# Get raw data
global outfilepath
sampleName='jfh1v2'
outfilepath=os.getcwd() + '/results/%s/'%sampleName
print outfilepath
# Out:
# /arrayAhome/lmartin/CLIP/results/jfh1v2/

# %%
def modifyName(filepath,newTag):
	# Useage: Modifies the filepath name. 
	# Input: File path of format <path>/<name>.fastq and a string to add to the name.
	# Output: Returns the modified path of type <old path>_<new modifier>.fastq
    head, tail = os.path.split(filepath)
    oldname = tail.split('.')[0]
    newName = head+"/"+oldname+"_"+newTag
    return newName

def runBowtie(fastqFiles,viralGenome):
    # Useage: Short read mapping to reference (hg19).
    # Input: Fastq files of replicates (not paired end).
    # Output: Path to samfile for each read.
    program = 'bowtie2'
    mappedReads=[]
    unMappedReads=[]
    print "Performing Bowtie..."
    # Parameters
    # In -k mode, Bowtie 2 searches for up to N distinct, valid alignments for each read.
    # N equals the integer specified with the -k parameter. 
    # That is, if -k 2 is specified, Bowtie 2 will search for at most 2 distinct alignments
    # See http://bowtie-bio.sourceforge.net/bowtie2/manual.shtml
    for infastq in fastqFiles:

        index = os.getcwd() + '/docs/%s/%s'%(viralGenome,viralGenome)
        outfile = modifyName(infastq,"mappedTo%s.sam"%viralGenome)
        unmapped = modifyName(infastq,"notMappedTo%s.fastq"%viralGenome)
        
        print "Input file:"
        print infastq 
        print 'Genome index:'
        print index
        print "Output file (mapped):"
        print outfile
        print "Output file (unmapped)"
        print unmapped
        # Remove -a
        proc = subprocess.Popen([program,'-x', index,'-U',infastq,'--un',unmapped,'-S',outfile],stdout=subprocess.PIPE,stderr=subprocess.PIPE)
        out, err = proc.communicate()
        result = out.decode()
        error = err.decode()
        print "Result : ",result 
        print "Error : ",error
        mappedReads = mappedReads + [outfile]
        unMappedReads = unMappedReads + [unmapped]
    return (mappedReads,unMappedReads)

def runSamtools(samfiles):
    # Useage: Samfile processing.
    # Input: Sam files from Bowtie mapping.
    # Output: Duplicate removed, sorted bedFiles.
    program = 'samtools'
    program2 = 'bamToBed'
    outBedFiles=[]
    
    for samfile in samfiles:
            
        # Convert to bamfile
        bamfile = samfile.replace('.sam', '.bam')  
        proc = subprocess.Popen( [program, 'view', '-bS', '-o', bamfile, samfile])
        proc.communicate()
        
        # Sort the bamfile and note that samtools sort adds the .bam handle
        bamfile_sort = bamfile.replace('.bam', '_sorted') 
        proc2 = subprocess.Popen( [program, 'sort', bamfile, bamfile_sort])
        proc2.communicate()
        
        # Convert to bedFile
        bedFile = bamfile_sort.replace('_sorted', '_withDupes.bed')
        outfh = open(bedFile, 'w')
        proc3 = subprocess.Popen( [program2,'-i', bamfile_sort+'.bam'],stdout=outfh)
        proc3.communicate()
        
        outBedFiles=outBedFiles+[bedFile]
        
    return outBedFiles

# Run bowtie
print "Mapping to viral index."  
trimmedReads5p=glob.glob(outfilepath+'*5ptrimmed.fastq')
mappedReads,unMappedReads=runBowtie(trimmedReads5p,'jfh1')

# Run Samtools
print "Process mapped data"  
mappedBedFiles=runSamtools(mappedReads)
# Out:
# Mapping to viral index.
# Performing Bowtie...
# Input file:
# /arrayAhome/lmartin/CLIP/results/hcvwt/hcvwt_R2_3ptrimmed_filter_nodupe_5ptrimmed.fastq
# Genome index:
# /arrayAhome/lmartin/CLIP/docs/jfh1/jfh1
# Output file (mapped):
# /arrayAhome/lmartin/CLIP/results/hcvwt/hcvwt_R2_3ptrimmed_filter_nodupe_5ptrimmed_mappedTojfh1.sam
# Output file (unmapped)
# /arrayAhome/lmartin/CLIP/results/hcvwt/hcvwt_R2_3ptrimmed_filter_nodupe_5ptrimmed_notMappedTojfh1.fastq
# Result :

# %% [markdown]
# #### Process -

# %%
# Index
outfilepathjfh1=os.getcwd() + '/docs/jfh1/HCV_JFHAB047639.fa'
jfh1_genome=np.genfromtxt(outfilepathjfh1,dtype='string')
jfh1_genome_size=len(jfh1_genome[1])

# Data frames to store HCV data
storageDFHCV=pd.DataFrame()
indexPositions=np.arange(0,jfh1_genome_size,1)
storeGenomeHits=pd.DataFrame(index=indexPositions)

# %%
# Process mapped files
mappedBedFiles1=[]
sampleName='jfh1v2'
outfilepathjfh1=os.getcwd() + '/results/'+sampleName+'/'
mappedBedFiles2=glob.glob(outfilepathjfh1+'*mappedTojfh1_withDupes.bed')
sampleName='hcvwt'
outfilepathjfh1=os.getcwd() + '/results/'+sampleName+'/'
mappedBedFiles3=glob.glob(outfilepathjfh1+'*mappedTojfh1_withDupes.bed')
mappedBedFiles=mappedBedFiles1+mappedBedFiles2+mappedBedFiles3

# Global plotting stats
bins=np.array(range(0,jfh1_genome_size,5)) # Bin the genome by 5 bp
width=0.7*(bins[1]-bins[0]) # Bar width for plotting
center=(bins[:-1]+bins[1:])/2 # Center position of each bin

# Compute histogram for each
coverageHistograms=[]
for bedFile in mappedBedFiles:
    
    handle=os.path.split(bedFile)[1].split('_3ptrimmed')[0]
    data=np.genfromtxt(bedFile,usecols=(1,),delimiter='\t',dtype='int') # Read the 5' coordinate (RT stop).
    hist,bins=np.histogram(data,bins=bins) # Compute histogram.
    
    storageDFHCV[handle+'_raw']=hist
    hist=hist/float(len(data)) # Normalize to total number of reads mapped to viral genome.
    storageDFHCV[handle+'_norm']=hist
    coverageHistograms.append(hist)
    
    genomeHits=pd.DataFrame(data)
    genomeHits.columns=['RT_stop_position']
    hits=genomeHits.groupby('RT_stop_position').size()
    storeGenomeHits[handle+'_rawReads']=hits

storageDFHCV['Bin_Center']=center
bases=[jfh1_genome[1][pos] for pos in center]
storageDFHCV['Base']=bases
storageDFHCV.index=storageDFHCV['Base']
    
bases=[jfh1_genome[1][pos] for pos in storeGenomeHits.index]
storeGenomeHits['Base']=bases
storeGenomeHits.fillna(0,inplace=True)
saveName='JFH-1_CLIP_RawData'
storeGenomeHits.to_csv(outfilepath+saveName)

# %%
print storeGenomeHits.groupby('Base').jfh1v2_R1_rawReads.sum()/storeGenomeHits['jfh1v2_R1_rawReads'].sum()
print storeGenomeHits.groupby('Base').jfh1v2_R2_rawReads.sum()/storeGenomeHits['jfh1v2_R2_rawReads'].sum()
# Out:
# Base
# A       0.078587
# C       0.287547
# G       0.071360
# T       0.562506
# Name: jfh1v2_R1_rawReads, dtype: float64
# Base
# A       0.067809
# C       0.293841
# G       0.066292
# T       0.572057
# Name: jfh1v2_R2_rawReads, dtype: float64

# %%
cutoff=5
tmpR1=storeGenomeHits[storeGenomeHits['jfh1v2_R1_rawReads']>cutoff]
tmpR2=storeGenomeHits[storeGenomeHits['jfh1v2_R2_rawReads']>cutoff]
print tmpR1.groupby('Base').jfh1v2_R1_rawReads.sum()/tmpR1['jfh1v2_R1_rawReads'].sum()
print tmpR2.groupby('Base').jfh1v2_R2_rawReads.sum()/tmpR2['jfh1v2_R2_rawReads'].sum()
# Out:
# Base
# A       0.044455
# C       0.274061
# G       0.032189
# T       0.649296
# Name: jfh1v2_R1_rawReads, dtype: float64
# Base
# A       0.022937
# C       0.256262
# G       0.014237
# T       0.706565
# Name: jfh1v2_R2_rawReads, dtype: float64

# %%
storeGenomeHits.tail(150)
# Out:
#       jfh1v2_R1_rawReads  jfh1v2_R2_rawReads  hcvwt_R1_rawReads  \
# 9528                  10                   1                  0
# 9529                  11                   0                  0
# 9530                  13                   2                  0
# 9531                  19                   1                  0
# 9532                  37                   3                  0
# 9533                  90                  19                  0
# 9534                 174                  31                  0
# 9535                 115                  14                  0
# 9536                  87                  17                  0
# 9537                  13                   3                  0
# 9538                  52                   6                  0
# 9539                  34                  12                  0
# 9540                  38                  14                  0
# 9541                  22                  17                  0
# 9542                  42                  21                  0
# 9543                  18                   4                  0
# 9544                  28                   4                  0
# 9545                  63                  11                  0
# 9546                  12                   8                  0
# 9547                  13                   4                  0
# 9548                   7                   1                  0
# 9549                   7                   0                  0
# 9550                   7                   0                  0
# 9551                   1                   0                  0
# 9552                   5                   0                  0
# 9553                  18                   3                  0
# 9554                  12                   3                  0
# 9555                  13                   2                  0
# 9556                   6                   1                  0
# 9557                  98                  26                  0
# 9558                  11                   2                  0
# 9559                   9                   4                  0
# 9560                  26                   8                  0
# 9561                  29                  12                  0
# 9562                  61                  17                  0
# 9563                  17                   5                  0
# 9564                  24                   5                  0
# 9565                   8                   1                  0
# 9566                  11                   1                  0
# 9567                 104                  26                  0
# 9568                   3                   2                  0
# 9569                   8                   1                  0
# 9570                  41                  12                  0
# 9571                  84                  16                  0
# 9572                  31                  12                  0
# 9573                  24                   2                  0
# 9574                  64                  23                  0
# 9575                  98                  12                  0
# 9576                  39                   7                  0
# 9577                  10                   5                  0
# 9578                  38                   7                  0
# 9579                  27                   9                  0
# 9580                   2                   1                  0
# 9581                   0                   1                  3
# 9582                   1                   1                  0
# 9583                   1                   1                  0
# 9584                   2                   2                  0
# 9585                   6                   0                  0
# 9586                  21                   5                  0
# 9587                   3                   0                  0
#                      ...                 ...                ...
#
#       hcvwt_R2_rawReads Base
# 9528                  0    T
# 9529                  0    T
# 9530                  0    T
# 9531                  0    T
# 9532                  0    T
# 9533                  0    T
# 9534                  0    T
# 9535                  0    T
# 9536                  0    T
# 9537                  0    T
# 9538                  0    T
# 9539                  0    C
# 9540                  0    C
# 9541                  0    C
# 9542                  0    T
# 9543                  0    C
# 9544                  0    T
# 9545                  0    T
# 9546                  0    T
# 9547                  0    C
# 9548                  0    T
# 9549                  0    T
# 9550                  0    C
# 9551                  0    C
# 9552                  0    C
# 9553                  0    T
# 9554                  0    T
# 9555                  0    C
# 9556                  0    T
# 9557                  0    C
# 9558                  0    A
# 9559                  0    T
# 9560                  0    C
# 9561                  0    T
# 9562                  0    T
# 9563                  0    A
# 9564                  0    T
# 9565                  0    T
# 9566                  0    C
# 9567                  0    T
# 9568                  0    A
# 9569                  0    C
# 9570                  0    T
# 9571                  0    T
# 9572                  0    T
# 9573                  0    C
# 9574                  0    T
# 9575                  0    T
# 9576                  0    T
# 9577                  1    C
# 9578                  0    T
# 9579                  0    T
# 9580                  0    G
# 9581                  0    G
# 9582                  0    T
# 9583                  0    G
# 9584                  0    G
# 9585                  0    C
# 9586                  0    T
# 9587                  0    C
#                     ...  ...
#
# [150 rows x 5 columns]

# %%
storageDFHCV.tail(50)
# Out:
#       jfh1v2_R1_raw  jfh1v2_R1_norm  jfh1v2_R2_raw  jfh1v2_R2_norm  \
# Base
# C               586        0.028046            191        0.028975
# C                16        0.000766              5        0.000758
# G               332        0.015890             88        0.013350
# A                 5        0.000239              6        0.000910
# C                99        0.004738             58        0.008799
# A               159        0.007610             93        0.014108
# G                31        0.001484             18        0.002731
# C                17        0.000814              7        0.001062
# T                 8        0.000383              6        0.000910
# A                 8        0.000383              2        0.000303
# T               126        0.006030             63        0.009557
# T               627        0.030009            282        0.042779
# T               452        0.021633            216        0.032767
# T               408        0.019527            210        0.031857
# T               475        0.022734            220        0.033374
# T               441        0.021107            215        0.032615
# T                58        0.002776             17        0.002579
# T                 6        0.000287              5        0.000758
# T                10        0.000479              1        0.000152
# T                 7        0.000335              1        0.000152
# T                42        0.002010              6        0.000910
# T               333        0.015938             56        0.008495
# T               301        0.014406             52        0.007888
# T               148        0.007083             60        0.009102
# C               102        0.004882             24        0.003641
# C                43        0.002058              6        0.000910
# C               137        0.006557             35        0.005309
# T               157        0.007514             47        0.007130
# T               134        0.006413             31        0.004703
# T               244        0.011678             65        0.009860
# C               212        0.010146             40        0.006068
# T                 6        0.000287              6        0.000910
# C                39        0.001867             14        0.002124
# T                32        0.001532              4        0.000607
# C                 3        0.000144              4        0.000607
# T                 3        0.000144              0        0.000000
# G                 4        0.000191              2        0.000303
# C                 1        0.000048              1        0.000152
# A                 6        0.000287              1        0.000152
# T                 2        0.000096              1        0.000152
# G                 3        0.000144              2        0.000303
# G                 5        0.000239              1        0.000152
# A                 1        0.000048              0        0.000000
# A                 0        0.000000              0        0.000000
# G                 1        0.000048              1        0.000152
# G                 9        0.000431              3        0.000455
# T                 1        0.000048              3        0.000455
# T                 0        0.000000              0        0.000000
# G                 0        0.000000              0        0.000000
# T                 0        0.000000              0        0.000000
#
#       hcvwt_R1_raw  hcvwt_R1_norm  hcvwt_R2_raw  hcvwt_R2_norm  Bin_Center  \
# Base
# C                0       0.000000             0       0.000000        9427
# C                0       0.000000             0       0.000000        9432
# G                0       0.000000             0       0.000000        9437
# A                0       0.000000             0       0.000000        9442
# C                0       0.000000             0       0.000000        9447
# A                0       0.000000             0       0.000000        9452
# G                0       0.000000             0       0.000000        9457
# C                0       0.000000             0       0.000000        9462
# T                0       0.000000             0       0.000000        9467
# A                2       0.006390             1       0.003165        9472
# T               16       0.051118             9       0.028481        9477
# T              116       0.370607           115       0.363924        9482
# T               57       0.182109            51       0.161392        9487
# T               46       0.146965            41       0.129747        9492
# T               32       0.102236            35       0.110759        9497
# T               22       0.070288            40       0.126582        9502
# T                1       0.003195             0       0.000000        9507
# T                0       0.000000             2       0.006329        9512
# T                0       0.000000             2       0.006329        9517
# T                0       0.000000             0       0.000000        9522
# T                0       0.000000             0       0.000000        9527
# T                0       0.000000             0       0.000000        9532
# T                0       0.000000             0       0.000000        9537
# T                0       0.000000             0       0.000000        9542
# C                0       0.000000             0       0.000000        9547
# C                0       0.000000             0       0.000000        9552
# C                0       0.000000             0       0.000000        9557
# T                0       0.000000             0       0.000000        9562
# T                0       0.000000             0       0.000000        9567
# T                0       0.000000             0       0.000000        9572
# C                0       0.000000             1       0.003165        9577
# T                3       0.009585             0       0.000000        9582
# C                0       0.000000             0       0.000000        9587
# T                0       0.000000             0       0.000000        9592
# C                0       0.000000             0       0.000000        9597
# T                0       0.000000             0       0.000000        9602
# G                0       0.000000             0       0.000000        9607
# C                0       0.000000             0       0.000000        9612
# A                0       0.000000             0       0.000000        9617
# T                0       0.000000             0       0.000000        9622
# G                0       0.000000             0       0.000000        9627
# G                0       0.000000             0       0.000000        9632
# A                0       0.000000             0       0.000000        9637
# A                0       0.000000             0       0.000000        9642
# G                0       0.000000             0       0.000000        9647
# G                0       0.000000             0       0.000000        9652
# T                0       0.000000             0       0.000000        9657
# T                0       0.000000             0       0.000000        9662
# G                0       0.000000             0       0.000000        9667
# T                0       0.000000             0       0.000000        9672
#
#      Base  JFH-1_CLIP_Rep_1  JFH-1_CLIP_Rep_2
# Base
# C       C          0.028046          0.028975
# C       C          0.000766          0.000758
# G       G          0.015890          0.013350
# A       A          0.000239          0.000910
# C       C          0.004738          0.008799
# A       A          0.007610          0.014108
# G       G          0.001484          0.002731
# C       C          0.000814          0.001062
# T       T          0.000383          0.000910
# A       A          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000000          0.000000
# T       T          0.000335          0.000152
# T       T          0.002010          0.000910
# T       T          0.015938          0.008495
# T       T          0.014406          0.007888
# T       T          0.007083          0.009102
# C       C          0.004882          0.003641
# C       C          0.002058          0.000910
# C       C          0.006557          0.005309
# T       T          0.007514          0.007130
# T       T          0.006413          0.004703
# T       T          0.011678          0.009860
# C       C          0.000000          0.000000
# T       T          0.000000          0.000000
# C       C          0.001867          0.002124
# T       T          0.001532          0.000607
# C       C          0.000144          0.000607
# T       T          0.000144          0.000000
# G       G          0.000191          0.000303
# C       C          0.000048          0.000152
# A       A          0.000287          0.000152
# T       T          0.000096          0.000152
# G       G          0.000144          0.000303
# G       G          0.000239          0.000152
# A       A          0.000048          0.000000
# A       A          0.000000          0.000000
# G       G          0.000048          0.000152
# G       G          0.000431          0.000455
# T       T          0.000048          0.000455
# T       T          0.000000          0.000000
# G       G          0.000000          0.000000
# T       T          0.000000          0.000000
#
# [50 rows x 12 columns]

# %% [markdown]
# #### Check -

# %%
data=np.genfromtxt(mappedBedFiles2[0],usecols=(1,),delimiter='\t',dtype='int') # Read the 5' coordinate (RT stop).
print len(data[data==0])
data=np.genfromtxt(mappedBedFiles2[1],usecols=(1,),delimiter='\t',dtype='int') # Read the 5' coordinate (RT stop).
print len(data[data==3])
# Out:
# 107
# 12

# %%
reads=pd.read_table(mappedBedFiles2[0],header=None)
reads.columns=['ReadName','Start','End','M1','M2','Strand']
reads[reads['Start']==0].shape
# Out:
# (107, 6)

# %% [markdown]
# #### Store filtered data -

# %%
# Histograms to filter
HistToFilter=[0,1] # jfh1v2
Background=[2,3] # hcvwt
filteredHist=[]
# For each histogram
for i in HistToFilter:
    # Copy the values into temp object
    tempHist=coverageHistograms[i]
    # For each index in the histogram
    for index in range(0,len(tempHist)):
        # Check if background histograms (no infection) have counts
        if coverageHistograms[Background[0]][index] > 0 or coverageHistograms[Background[1]][index] > 0:
            # If so, then do not count
            tempHist[index]=0
    filteredHist.append(tempHist)

# %%
# Save final data
storageDFHCV['JFH-1_CLIP_Rep_1']=filteredHist[0]
storageDFHCV['JFH-1_CLIP_Rep_2']=filteredHist[1]
saveName='JFH-1_CLIP_CoverageData'
storageDFHCV.to_csv(outfilepath+saveName)

# %%
# Scatter plot
geneType='HCV genome'
sampleName1='JFH-1 Rep1'
sampleName2='JFH-1 Rep2'
 
# Compute based upon histograms bins
bins=np.array(range(0,jfh1_genome_size,5)) # Bin the genome by 5 bp
width=0.7*(bins[1]-bins[0]) # Bar width for plotting
center=(bins[:-1] + bins[1:])/2 # Center position of each bin

# Annotation
UTR5end=340
UTR3start=9280

# Isolate UTR data from new JFH-1 histograms
boolarray=[element < UTR5end or element > UTR3start for element in center]
boolarray=np.array(boolarray,dtype=bool)
center=center[boolarray]
sample1=filteredHist[0][boolarray]
sample2=filteredHist[1][boolarray]

# Fit_fn is now a function which takes in x and returns an estimate for y
fit = np.polyfit(sample1,sample2,1)
fit_fn = np.poly1d(fit)
slope,intercept,r_value,p_value,std_err=scipy.stats.linregress(sample1,sample2)
print "r-squared:", r_value**2

fig1=plt.figure(1)

plt.subplot(2,2,2)
for i in range(0,len(center)):
    # Get position at the point
    position=center[i]
    # Annotate
    if position < UTR5end:
        color='blue'
        plt.scatter(sample1[i],sample2[i],color=color,alpha=0.35) 
    elif position > UTR3start:
        color='red'
        plt.scatter(sample1[i],sample2[i],color=color,alpha=0.35)
plt.plot(sample1,fit_fn(sample1),alpha=0.5,color='black')
# plt.xlabel("Normalized gene read count: %s"%sampleName1,fontsize=5)
# plt.ylabel("Normalized gene read count: %s"%sampleName2,fontsize=5)
plt.tick_params(axis='xticks',labelsize=5) 
plt.tick_params(axis='yticks',labelsize=5)
plt.xticks(rotation=90,fontsize=5)

plt.yticks(fontsize=5)
plt.tight_layout()	

fig1.savefig(outfilepath+'ViralScatter.png',format='png',bbox_inches='tight',dpi=200,pad_inches=0.5)
fig1.savefig(outfilepath+'ViralScatter.pdf',format='pdf',bbox_inches='tight',dpi=200,pad_inches=0.5)
# Out:
# r-squared: 0.933532945875

# %%
utr5p=storageDFHCV[storageDFHCV['Bin_Center']<400]
utr3p=storageDFHCV[storageDFHCV['Bin_Center']>9280]

fig2=plt.figure(2)

plt.subplot(2,2,1)
color='blue'
plt.bar(utr5p['Bin_Center'],utr5p['JFH-1_CLIP_Rep_1'],align='center',width=width,color=color,alpha=0.3)
plt.bar(utr5p['Bin_Center'],utr5p['JFH-1_CLIP_Rep_2'],align='center',width=width,color=color,alpha=0.3)
plt.tick_params(axis='x',labelsize=5)
plt.tick_params(axis='y',labelsize=5)
plt.xlim([-10,400])

plt.subplot(2,2,2)
color='red'
plt.bar(utr3p['Bin_Center'],utr3p['JFH-1_CLIP_Rep_1'],align='center',width=width,color=color,alpha=0.3)
plt.bar(utr3p['Bin_Center'],utr3p['JFH-1_CLIP_Rep_2'],align='center',width=width,color=color,alpha=0.3)
plt.tick_params(axis='x',labelsize=5)
plt.tick_params(axis='y',labelsize=5)
plt.xlim([9280,jfh1_genome_size+10])

fig2.savefig(outfilepath+'ViralUTRs.png',format='png',bbox_inches='tight',dpi=150,pad_inches=0.5)
fig2.savefig(outfilepath+'ViralUTRs.pdf',format='pdf',bbox_inches='tight',dpi=150,pad_inches=0.5)

# %%
fig3=plt.figure(3)

# Compute based upon histograms bins
bins=np.array(range(0,jfh1_genome_size,5)) # Bin the genome by 5 bp
width=0.7*(bins[1]-bins[0]) # Bar width for plotting
center=(bins[:-1] + bins[1:])/2 # Center position of each bin

# Scatter plot
geneType='HCV genome'
sampleName1='JFH-1 Rep1'
sampleName2='JFH-1 Rep2'

# Annotation
UTR5end=340
UTR3start=9280
 
# Fit_fn is now a function which takes in x and returns an estimate for y
fit=np.polyfit(filteredHist[0],filteredHist[1],1)
fit_fn=np.poly1d(fit)
slope,intercept,r_value,p_value,std_err=scipy.stats.linregress(filteredHist[0],filteredHist[1])
print "r-squared:", r_value**2

# Iterate through cdenter index of each bin
plt.subplot(1,2,1)
for i in range(0,len(center)):
    # Get position at the point
    position=center[i]
    # Annotate
    if position < UTR5end:
        color='blue'
    elif position > UTR3start:
        color='red'
    else:
        color='cyan'
    # Extract points from newer JFH-1 data histograms
    plt.scatter(filteredHist[0][i],filteredHist[1][i],color=color,alpha=0.35)
    plt.tick_params(axis='x',labelsize=5)
    plt.tick_params(axis='y',labelsize=5)
plt.plot(filteredHist[0],fit_fn(filteredHist[0]),alpha=0.5,color='black')
plt.xlabel("Normalized gene read count: %s"%sampleName1,fontsize=5)
plt.ylabel("Normalized gene read count: %s"%sampleName2,fontsize=5)
plt.title("Comparison for %s"%geneType)
#plt.tick_params(axis='xticks',labelsize=5) 
#plt.tick_params(axis='yticks',labelsize=5)
plt.xticks(rotation=90)
maxVal=0.04
plt.xlim(-0.1*maxVal,maxVal)
plt.ylim(-0.1*maxVal,maxVal)

fig3.savefig(outfilepath+'S4_HCV_fullGenomeCoor_Supp.png',format='png',bbox_inches='tight',dpi=200,pad_inches=0.5)
fig3.savefig(outfilepath+'S4_HCV_fullGenomeCoor_Supp.pdf',format='pdf',bbox_inches='tight',dpi=200,pad_inches=0.5)
# Out:
# r-squared: 0.903140669239

# %%
fig4=plt.figure(4)

color='cyan'

plt.subplot2grid((2,3),(0,0),colspan=3)
for i in range(0,2): # Full genome 
    plt.bar(center,filteredHist[i],align='center',width=width,color=color,alpha=0.3)
    plt.tick_params(axis='x',labelsize=5)
    plt.tick_params(axis='y',labelsize=5)
plt.title("Coverage histogram for JFH-1.",fontsize=7.5)
plt.ylim([0,0.04])

plt.subplot2grid((2,3),(1,0),colspan=1)
for i in range(0,2):    
    plt.bar(center,filteredHist[i],align='center',width=width,color=color,alpha=0.3)
    plt.tick_params(axis='x',labelsize=5)
    plt.tick_params(axis='y',labelsize=5)
plt.xlim([400,2500])
plt.ylim([0,0.01])

plt.subplot2grid((2,3),(1,1),colspan=1)
for i in range(0,2):    
    plt.bar(center,filteredHist[i],align='center',width=width,color=color,alpha=0.3)
    plt.tick_params(axis='x',labelsize=5)
    plt.tick_params(axis='y',labelsize=5)
plt.xlim([6000,7000])
plt.ylim([0,0.01])

plt.subplot2grid((2,3),(1,2),colspan=1)
for i in range(0,2):    
    plt.bar(center,filteredHist[i],align='center',width=width,color=color,alpha=0.3)
    plt.tick_params(axis='x',labelsize=5)
    plt.tick_params(axis='y',labelsize=5)
plt.xlim([8000,9280])
plt.ylim([0,0.01])
plt.tight_layout()

fig4.savefig(outfilepath+'S5_HCV_fullGenomeCoor_hist_Supp.png',format='png',bbox_inches='tight',dpi=200,pad_inches=0.5)
fig4.savefig(outfilepath+'S5_HCV_fullGenomeCoor_hist_Supp.pdf',format='pdf',bbox_inches='tight',dpi=200,pad_inches=0.5)
